# %%
from typing import Type, TypeVar
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d.axes3d import Axes3D
import cv2

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection="3d")

ls = np.linspace(-20, 20, 100)
xx, yy = np.meshgrid(ls, ls)

zz = xx**2 + yy**2
ax.plot_surface(xx, yy, zz)
# ax.plot(xx[10], yy[10])
# ax.plot([xx[10,10]], [yy[10,10]], [10])
# ax.plot([5], [5])
ax.plot(xx[10], yy[10])
# ax.plot(xx[10], yy[10], xx[50])
plt.show()
# print(xx[10,10])

# %%
import sympy

# %%
x = sympy.Symbol("x")
y = sympy.Symbol("y")

# %%
x
# Out:
# x

# %%
y
# Out:
# y

# %%
x * y
# Out:
# x*y

# %%
x ** y
# Out:
# x**y

# %%
x ** 0.5
# Out:
# x**0.5

# %%
sympy.sqrt(x)
# Out:
# sqrt(x)

# %%
f = x**2 * y + y**2 * x
f
# Out:
# x**2*y + x*y**2

# %%
sympy.diff(f, x)
# Out:
# 2*x*y + y**2

# %%
f = x**2 * y + y**2 * x
i = 0
while (i < 10):
    f = sympy.integrate(f, x)
    # f = sympy.diff(f, x)
    print(f)
    i += 1
# Out:
# x**3*y/3 + x**2*y**2/2
# x**4*y/12 + x**3*y**2/6
# x**5*y/60 + x**4*y**2/24
# x**6*y/360 + x**5*y**2/120
# x**7*y/2520 + x**6*y**2/720
# x**8*y/20160 + x**7*y**2/5040
# x**9*y/181440 + x**8*y**2/40320
# x**10*y/1814400 + x**9*y**2/362880
# x**11*y/19958400 + x**10*y**2/3628800
# x**12*y/239500800 + x**11*y**2/39916800

# %%
sympy.diff(f, y)
# Out:
# x**2 + 2*x*y

# %%
sympy.integrate(f, y)
# Out:
# x**2*y**2/2 + x*y**3/3
